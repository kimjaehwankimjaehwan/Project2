# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/Project2/blob/main/Preprocessing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_2017 전체.csv',encoding='cp949')

df.head()
# Out:
# <ipython-input-13-007b9f5d29b1>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_2017 전체.csv',encoding='cp949')
#    지점 지점명               일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  90  속초  2017-01-01 1:00     3.4       0.0      NaN        NaN      1.4
# 1  90  속초  2017-01-01 2:00     4.6       0.0      NaN        NaN      2.3
# 2  90  속초  2017-01-01 3:00     4.1       0.0      NaN        NaN      1.4
# 3  90  속초  2017-01-01 4:00     3.7       0.0      NaN        NaN      1.0
# 4  90  속초  2017-01-01 5:00     4.1       0.0      NaN        NaN      1.4
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       0.0     250.0  ...          NaN   1883.0           NaN        NaN
# 1       0.0     320.0  ...          NaN   2000.0           NaN        NaN
# ...

# %%
filtered_df = df[df['지점'].isin([105, 100, 106, 104, 93, 214, 90, 121, 114, 211, 217, 95, 101, 216, 212])]

# %%
filtered_df.head()
# Out:
#    지점 지점명               일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  90  속초  2017-01-01 1:00     3.4       0.0      NaN        NaN      1.4
# 1  90  속초  2017-01-01 2:00     4.6       0.0      NaN        NaN      2.3
# 2  90  속초  2017-01-01 3:00     4.1       0.0      NaN        NaN      1.4
# 3  90  속초  2017-01-01 4:00     3.7       0.0      NaN        NaN      1.0
# 4  90  속초  2017-01-01 5:00     4.1       0.0      NaN        NaN      1.4
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       0.0     250.0  ...          NaN   1883.0           NaN        NaN
# 1       0.0     320.0  ...          NaN   2000.0           NaN        NaN
# 2       0.0     270.0  ...          NaN   1986.0           NaN        NaN
# 3       0.0     230.0  ...          NaN   2000.0           NaN        NaN
# 4       0.0     250.0  ...          NaN   2000.0           NaN        NaN
#
#    지면온도(°C)  지면온도 QC플래그  5cm 지중온도(°C)  10cm 지중온도(°C)  20cm 지중온도(°C)  \
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 122299 entries, 0 to 471602
# Data columns (total 38 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   지점             122299 non-null  int64
#  1   지점명            122299 non-null  object
#  2   일시             122299 non-null  object
#  3   기온(°C)         122287 non-null  float64
#  4   기온 QC플래그       121949 non-null  float64
#  5   강수량(mm)        10952 non-null   float64
#  6   강수량 QC플래그      30505 non-null   float64
#  7   풍속(m/s)        122289 non-null  float64
#  8   풍속 QC플래그       110222 non-null  float64
#  9   풍향(16방위)       122289 non-null  float64
#  10  풍향 QC플래그       110222 non-null  float64
#  11  습도(%)          122204 non-null  float64
#  12  습도 QC플래그       121949 non-null  float64
#  13  증기압(hPa)       122225 non-null  float64
#  14  이슬점온도(°C)      122223 non-null  float64
#  15  현지기압(hPa)      122285 non-null  float64
#  16  현지기압 QC플래그     121949 non-null  float64
# ...

# %%
selected_columns = [
    '일시', '기온(°C)',  '강수량(mm)',
    '풍속(m/s)',  '풍향(16방위)', '습도(%)',
    '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
    '해면기압(hPa)', '일조(hr)',  '일사(MJ/m2)',
    '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
    '최저운고(100m )', '시정(10m)',
    '지면온도(°C)',  '5cm 지중온도(°C)',
    '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'
]
filtered_df = filtered_df[selected_columns]
filtered_df.head()
# Out:
#                 일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  증기압(hPa)  \
# 0  2017-01-01 1:00     3.4      NaN      1.4     250.0   53.0       4.2
# 1  2017-01-01 2:00     4.6      NaN      2.3     320.0   48.0       4.1
# 2  2017-01-01 3:00     4.1      NaN      1.4     270.0   49.0       4.0
# 3  2017-01-01 4:00     3.7      NaN      1.0     230.0   48.0       3.8
# 4  2017-01-01 5:00     4.1      NaN      1.4     250.0   46.0       3.8
#
#    이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  ...  3시간신적설(cm)  전운량(10분위)  중하층운량(10분위)  \
# 0       -5.2     1024.3     1026.6  ...         NaN        NaN          NaN
# 1       -5.4     1024.1     1026.4  ...         NaN        NaN          NaN
# 2       -5.6     1024.3     1026.6  ...         NaN        NaN          NaN
# 3       -6.3     1023.9     1026.2  ...         NaN        NaN          NaN
# 4       -6.5     1023.7     1026.0  ...         NaN        NaN          NaN
#
# ...

# %%
grouped_df = filtered_df.groupby('일시').mean().reset_index()

print(grouped_df.head())
# Out:
#                  일시    기온(°C)  강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 0  2017-01-01 10:00  1.064286      NaN  1.735714  122.857143  72.857143
# 1  2017-01-01 11:00  2.892857      NaN  1.435714  158.571429  65.000000
# 2  2017-01-01 12:00  4.021429      NaN  2.014286  190.000000  60.857143
# 3  2017-01-01 13:00  5.121429      NaN  2.042857  184.285714  57.500000
# 4  2017-01-01 14:00  5.857143      NaN  2.435714  193.571429  54.928571
#
#    증기압(hPa)  이슬점온도(°C)    현지기압(hPa)    해면기압(hPa)  ...  3시간신적설(cm)  전운량(10분위)  \
# 0  4.571429  -4.071429  1003.400000  1030.164286  ...         NaN        6.5
# 1  4.557143  -4.178571  1003.271429  1029.835714  ...         NaN        7.5
# 2  4.714286  -3.735714  1002.257143  1028.685714  ...         NaN        6.5
# 3  4.907143  -3.135714  1001.242857  1027.557143  ...         NaN        7.0
# 4  4.985714  -2.835714  1000.571429  1026.792857  ...         NaN        6.5
#
#    중하층운량(10분위)  최저운고(100m )      시정(10m)  지면온도(°C)  5cm 지중온도(°C)  \
# ...

# %%
sorted_df = grouped_df.sort_values(by='일시', ascending=True).reset_index(drop=True)

print(sorted_df.head())
# Out:
#                  일시    기온(°C)  강수량(mm)   풍속(m/s)    풍향(16방위)      습도(%)  \
# 0  2017-01-01 10:00  1.064286      NaN  1.735714  122.857143  72.857143
# 1  2017-01-01 11:00  2.892857      NaN  1.435714  158.571429  65.000000
# 2  2017-01-01 12:00  4.021429      NaN  2.014286  190.000000  60.857143
# 3  2017-01-01 13:00  5.121429      NaN  2.042857  184.285714  57.500000
# 4  2017-01-01 14:00  5.857143      NaN  2.435714  193.571429  54.928571
#
#    증기압(hPa)  이슬점온도(°C)    현지기압(hPa)    해면기압(hPa)  ...  3시간신적설(cm)  전운량(10분위)  \
# 0  4.571429  -4.071429  1003.400000  1030.164286  ...         NaN        6.5
# 1  4.557143  -4.178571  1003.271429  1029.835714  ...         NaN        7.5
# 2  4.714286  -3.735714  1002.257143  1028.685714  ...         NaN        6.5
# 3  4.907143  -3.135714  1001.242857  1027.557143  ...         NaN        7.0
# 4  4.985714  -2.835714  1000.571429  1026.792857  ...         NaN        6.5
#
#    중하층운량(10분위)  최저운고(100m )      시정(10m)  지면온도(°C)  5cm 지중온도(°C)  \
# ...

# %%
sorted_df.to_csv('강원도_2017.csv', index=False, encoding='utf-8-sig')

# %%
regions = {
    '강원도_2017.csv' : [105, 100, 106, 104, 93, 214, 90, 121, 114, 211, 217, 95, 101, 216, 212],
    '경기도_2017.csv': [98, 119, 202, 203, 99],
    '경상남도_2017.csv' : [294, 284, 253, 295, 288, 255, 289, 257, 263, 192, 155, 162, 264, 285],
    '경상북도_2017.csv' : [283, 279, 273, 271, 137, 136, 277, 272, 281, 115, 130, 278, 276, 138],
    '광주광역시_2017.csv': [156],
    "대구광역시_2017.csv": [143],
    "대전광역시_2017.csv": [133],
    "부산광역시_2017.csv": [159, 296],
    '서울특별시_2017.csv': [108, 116],
    '울산광역시_2017.csv': [152],
    '인천광역시_2017.csv': [201, 102, 112],
    '전라남도_2017.csv': [259, 262, 266, 165, 164, 258, 174, 168, 252, 170, 260, 256, 175, 268, 261, 169],
    '전라북도_2017.csv': [172, 251, 140, 247, 243, 254, 244, 248, 146, 245],
    '제주도_2017.csv': [185, 189, 187, 188, 265, 184],
    '충청남도_2017.csv': [238, 235, 236, 129, 232, 177],
    '충청북도_2017.csv': [226, 181, 221, 131, 135, 127]
}

for file_name, 지점_list in regions.items():
  filtered_df_2 = df[df['지점'].isin(지점_list)]
  selected_columns = [
      '일시', '기온(°C)',  '강수량(mm)',
      '풍속(m/s)',  '풍향(16방위)', '습도(%)',
      '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
      '해면기압(hPa)', '일조(hr)',  '일사(MJ/m2)',
      '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
      '최저운고(100m )', '시정(10m)',
      '지면온도(°C)',  '5cm 지중온도(°C)',
      '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'
  ]
  filtered_df_2 = filtered_df_2[selected_columns]
  grouped_df_2 = filtered_df_2.groupby('일시').mean().reset_index()
  sorted_df_2 = grouped_df_2.sort_values(by='일시', ascending=True).reset_index(drop=True)
  sorted_df_2.to_csv(file_name, index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv('/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_2018 전체.csv',encoding='cp949')
df.head()
# Out:
# <ipython-input-31-410a8ea1338f>:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_2018 전체.csv',encoding='cp949')
#    지점 지점명               일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0  90  속초  2018-01-01 1:00    -2.1       0.0      NaN        NaN      1.7
# 1  90  속초  2018-01-01 2:00    -2.1       0.0      NaN        NaN      1.4
# 2  90  속초  2018-01-01 3:00    -2.2       0.0      NaN        NaN      0.9
# 3  90  속초  2018-01-01 4:00    -2.0       0.0      NaN        NaN      1.2
# 4  90  속초  2018-01-01 5:00    -1.7       0.0      NaN        NaN      1.4
#
#    풍속 QC플래그  풍향(16방위)  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  현상번호(국내식)  \
# 0       0.0     230.0  ...          NaN   2000.0           NaN        NaN
# 1       0.0     160.0  ...          NaN   2000.0           NaN        NaN
# ...

# %%
regions = {
    '강원도': [105, 100, 106, 104, 93, 214, 90, 121, 114, 211, 217, 95, 101, 216, 212],
    '경기도': [98, 119, 202, 203, 99],
    '경상남도': [294, 284, 253, 295, 288, 255, 289, 257, 263, 192, 155, 162, 264, 285],
    '경상북도': [283, 279, 273, 271, 137, 136, 277, 272, 281, 115, 130, 278, 276, 138],
    '광주광역시': [156],
    "대구광역시": [143],
    "대전광역시": [133],
    "부산광역시": [159, 296],
    '서울특별시': [108, 116],
    '울산광역시': [152],
    '인천광역시': [201, 102, 112],
    '전라남도': [259, 262, 266, 165, 164, 258, 174, 168, 252, 170, 260, 256, 175, 268, 261, 169],
    '전라북도': [172, 251, 140, 247, 243, 254, 244, 248, 146, 245],
    '제주도': [185, 189, 187, 188, 265, 184],
    '충청남도': [238, 235, 236, 129, 232, 177],
    '충청북도': [226, 181, 221, 131, 135, 127]
}

for year in range(2017, 2024):
  df = pd.read_csv(f'/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_{year} 전체.csv',encoding='cp949')
  for region_name, 지점_list in regions.items():

      filtered_df_2 = df[df['지점'].isin(지점_list)]

      selected_columns = [
          '일시', '기온(°C)',  '강수량(mm)',
          '풍속(m/s)',  '풍향(16방위)', '습도(%)',
          '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)',
          '해면기압(hPa)', '일조(hr)',  '일사(MJ/m2)',
          '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
          '최저운고(100m )', '시정(10m)',
          '지면온도(°C)',  '5cm 지중온도(°C)',
          '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'
      ]
      filtered_df_2 = filtered_df_2[selected_columns]

      grouped_df_2 = filtered_df_2.groupby('일시').mean().reset_index()

      sorted_df_2 = grouped_df_2.sort_values(by='일시', ascending=True).reset_index(drop=True)

      file_name = f'{region_name}_{year}.csv'

      file_path = f'/content/drive/MyDrive/환경프로젝트/{file_name}'

      sorted_df_2.to_csv(file_path, index=False, encoding='utf-8-sig')

      print(f"{file_name} 저장 완료")
# Out:
# <ipython-input-36-75d511c072b3>:21: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_{year} 전체.csv',encoding='cp949')
# 강원도_2017.csv 저장 완료
# 경기도_2017.csv 저장 완료
# 경상남도_2017.csv 저장 완료
# 경상북도_2017.csv 저장 완료
# 광주광역시_2017.csv 저장 완료
# 대구광역시_2017.csv 저장 완료
# 대전광역시_2017.csv 저장 완료
# 부산광역시_2017.csv 저장 완료
# 서울특별시_2017.csv 저장 완료
# 울산광역시_2017.csv 저장 완료
# 인천광역시_2017.csv 저장 완료
# 전라남도_2017.csv 저장 완료
# 전라북도_2017.csv 저장 완료
# 제주도_2017.csv 저장 완료
# 충청남도_2017.csv 저장 완료
# 충청북도_2017.csv 저장 완료
# <ipython-input-36-75d511c072b3>:21: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'/content/drive/MyDrive/환경프로젝트/OBS_ASOS_TIM_{year} 전체.csv',encoding='cp949')
# 강원도_2018.csv 저장 완료
# 경기도_2018.csv 저장 완료
# 경상남도_2018.csv 저장 완료
# 경상북도_2018.csv 저장 완료
# 광주광역시_2018.csv 저장 완료
# 대구광역시_2018.csv 저장 완료
# ...
